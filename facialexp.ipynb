# %%
import cv2

# %%
from deepface import DeepFace

# %%
img=cv2.imread('happyboy.png')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) # BGR

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img,actions=['emotion'])

# %%
predictions
# Out:
# [{'emotion': {'angry': 7.028170905497289e-11,
#    'disgust': 3.170208927662295e-22,
#    'fear': 8.195062399410195e-13,
#    'happy': 99.99933242797852,
#    'sad': 1.6798443807307904e-12,
#    'surprise': 9.271403200727946e-05,
#    'neutral': 0.0005751239314122358},
#   'dominant_emotion': 'happy',
#   'region': {'x': 198,
#    'y': 0,
#    'w': 274,
#    'h': 274,
#    'left_eye': (366, 87),
#    'right_eye': (271, 129)},
#   'face_confidence': 0.96}]

# %%
type(predictions)
# Out:
# list

# %%
    if isinstance(predictions, list):
        dominant_emotion = predictions[0]['dominant_emotion']
        print("Dominant Emotion:", dominant_emotion)
# Out:
# Dominant Emotion: happy

# %%
#we are tring to draw a rectangle around the face

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())
faces=faceCascade.detectMultiScale(gray,1.1,4)
#draw a rectangle arund the face s
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
#Use putText() method for inserting text on video
cv2.putText(img,
                dominant_emotion,
                (50,50),
                font, 3,
                (0,255,0),
                2,
                cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img=cv2.imread('girl-2961959.jpg')

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img,actions=['emotion'])

# %%
predictions
# Out:
# [{'emotion': {'angry': 1.1721369810402393,
#    'disgust': 9.508539733360521e-06,
#    'fear': 2.130543813109398,
#    'happy': 0.0017029229638865218,
#    'sad': 14.725494384765625,
#    'surprise': 0.000698477606420056,
#    'neutral': 81.96941614151001},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 681,
#    'y': 302,
#    'w': 803,
#    'h': 803,
#    'left_eye': (1217, 585),
#    'right_eye': (896, 637)},
#   'face_confidence': 0.9}]
